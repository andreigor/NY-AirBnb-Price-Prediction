# %% [markdown]
# **Random Forest Modelling**

# %% [markdown]
# **Creating and Fitting Baseline Model**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pyspark.ml import Pipeline

import re
from pyspark.ml.tuning import ParamGridBuilder, TrainValidationSplit, CrossValidator
from pyspark.ml.regression import RandomForestRegressor

from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.mllib.evaluation import RegressionMetrics

df = spark.read.load("/FileStore/tables/airbnb_transf_dataframe_full")
X_train = spark.read.load("/FileStore/tables/airbnb_transf_dataframe_train")
X_test = spark.read.load("/FileStore/tables/airbnb_transf_dataframe_test")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Regression Evaluator
regression_evaluator_r2 = RegressionEvaluator(predictionCol="prediction", \
                 labelCol="log_price",metricName="r2")
regression_evaluator_rmse = RegressionEvaluator(predictionCol="prediction", \
                 labelCol="log_price",metricName="rmse")

# Random forest 

rfc_baseline = RandomForestRegressor(labelCol="log_price", featuresCol="simple_features") # Define the model

# Add to the stages list and create the pipeline object

pipeline_rfc_baseline = Pipeline(stages = [rfc_baseline])

evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="log_price", metricName="r2")

paramGrid = ParamGridBuilder() \
    .addGrid(rfc_baseline.maxDepth, [3,5,8]) \
    .addGrid(rfc_baseline.numTrees, [10,20,40]) \
    .build()

crossval = CrossValidator(estimator = pipeline_rfc_baseline,
                         estimatorParamMaps=paramGrid,
                         evaluator = evaluator,
                         numFolds = 5)

cvModel_rfc_baseline = crossval.fit(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:762: UserWarning: Cannot find mlflow module. To enable MLflow logging, install mlflow from PyPI.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %% [markdown]
# **Creating and Fitting Text Features Model**

# %%
# Random forest 

rfc_text_features = RandomForestRegressor(labelCol="log_price", featuresCol="features") # Define the model

# Add to the stages list and create the pipeline object

pipeline_rfc_text_features = Pipeline(stages = [rfc_text_features])

evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="log_price", metricName="r2")

paramGrid = ParamGridBuilder() \
    .addGrid(rfc_text_features.maxDepth, [3,5,8]) \
    .addGrid(rfc_text_features.numTrees, [10,20,40]) \
    .build()

crossval = CrossValidator(estimator = pipeline_rfc_text_features,
                         estimatorParamMaps=paramGrid,
                         evaluator = evaluator,
                         numFolds = 5)

cvModel_rfc_text_features = crossval.fit(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Evaluating the Models**

# %%
baseline_rmse = regression_evaluator_rmse.evaluate(cvModel_rfc_baseline.transform(X_test))


text_features_rmse = regression_evaluator_rmse.evaluate(cvModel_rfc_text_features.transform(X_test))


rmse = [baseline_rmse, text_features_rmse]
models = ['Baseline Model', 'Text Features Model']

fig, ax = plt.subplots(figsize = (20,15))
res = sns.barplot(models, rmse)
# Plot using seaborn
sns.set(font_scale = 4)
plt.title("Model's RMSE", fontsize = 20, fontweight = 'bold')
plt.xlabel('Models', fontsize = 16, fontweight = 'bold')
plt.ylabel('RMSE', fontsize = 16, fontweight = 'bold')
ax.grid(True)


plt.show()

# %% [markdown]
# **Comparing Models and Parameters**

# %%
data = {"baseline (r2 score)": cvModel_rfc_baseline.avgMetrics, "text_features (r2 score)":cvModel_rfc_text_features.avgMetrics}
results_df = pd.DataFrame(data=data)
results_df.index = [f"model_{i}" for i in range(9)]
display(results_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>baseline (r2 score)</th><th>text_features (r2 score)</th></tr></thead><tbody><tr><td>0.5188033105999454</td><td>0.5194749776111934</td></tr><tr><td>0.5195706551161526</td><td>0.517507948159052</td></tr><tr><td>0.5201589089173667</td><td>0.5232124416166679</td></tr><tr><td>0.5620417441060518</td><td>0.5721937246032165</td></tr><tr><td>0.5649583947667233</td><td>0.5733930137881565</td></tr><tr><td>0.5652452532994845</td><td>0.5740054585846722</td></tr><tr><td>0.6077995749112104</td><td>0.6196674610346197</td></tr><tr><td>0.6088485469327727</td><td>0.6199182629603502</td></tr><tr><td>0.610547449276157</td><td>0.6206883090184407</td></tr></tbody></table></div>

# %% [markdown]
# %md
#
# **Model 1**: {
#
#   maxDepth = 3
#
#   numTrees = 10
#
#
# }
#
# **Model 2**: {
#
#   maxDepth = 3
#
#   numTrees = 20
#
#
# }
#
# **Model 3**: {
#
#   maxDepth = 3
#
#   numTrees = 40
#
#
# }
#
# **Model 4**: {
#
#   maxDepth = 5
#
#   numTrees = 10
#
#
# }
#
# **Model 5**: {
#
#   maxDepth = 5
#
#   numTrees = 20
#
#
# }
#
# **Model 6**: {
#
#   maxDepth = 5
#
#   numTrees = 40
#
#
# }
#
# **Model 7**: {
#
#   maxDepth = 8
#
#   numTrees = 10
#
#
# }
#
# **Model 8**: {
#
#   maxDepth = 8
#
#   numTrees = 20
#
#
# }
#
# **Model 9**: {
#
#   maxDepth = 8
#
#   numTrees = 40
#
#
# }

# %% [markdown]
# **Visualizing Predictions**

# %%
predictions_baseline = cvModel_rfc_baseline.transform(X_test)

# Create a view or table

temp_table_name = "predictions_baseline_csv"

predictions_baseline.createOrReplaceTempView(temp_table_name)

predictions_text_features = cvModel_rfc_text_features.transform(X_test)

# Create a view or table

temp_table_name = "predictions_text_features_csv"

predictions_text_features.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql


SELECT log_price AS target, prediction
from predictions_baseline_csv
ORDER BY log_price
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>target</th><th>prediction</th></tr></thead><tbody><tr><td>2.3978952727983707</td><td>4.842634919394032</td></tr><tr><td>2.3978952727983707</td><td>4.096318150579006</td></tr><tr><td>2.3978952727983707</td><td>4.622380612823326</td></tr><tr><td>2.3978952727983707</td><td>4.068435672837218</td></tr><tr><td>2.3978952727983707</td><td>4.237708460715878</td></tr><tr><td>2.639057329615259</td><td>3.680606055589524</td></tr><tr><td>2.772588722239781</td><td>3.5424528227753767</td></tr><tr><td>2.772588722239781</td><td>5.513148592208181</td></tr><tr><td>2.833213344056216</td><td>5.023599360930381</td></tr><tr><td>3.044522437723423</td><td>3.95608107779022</td></tr><tr><td>3.044522437723423</td><td>3.4283421642863336</td></tr><tr><td>3.044522437723423</td><td>4.3201902272831445</td></tr><tr><td>3.044522437723423</td><td>4.976053210535451</td></tr><tr><td>3.044522437723423</td><td>4.118288634171795</td></tr><tr><td>3.044522437723423</td><td>3.8717533988454527</td></tr><tr><td>3.044522437723423</td><td>4.075032428551869</td></tr><tr><td>3.044522437723423</td><td>3.4699471057859497</td></tr><tr><td>3.044522437723423</td><td>4.0498709069581595</td></tr><tr><td>3.091042453358316</td><td>4.0546597831444195</td></tr><tr><td>3.091042453358316</td><td>4.064194711157211</td></tr><tr><td>3.1354942159291497</td><td>4.080035577521892</td></tr><tr><td>3.1354942159291497</td><td>4.060284721072621</td></tr><tr><td>3.1354942159291497</td><td>3.497441641672758</td></tr><tr><td>3.1354942159291497</td><td>3.958889058234626</td></tr><tr><td>3.1354942159291497</td><td>4.074608185731466</td></tr><tr><td>3.1780538303479458</td